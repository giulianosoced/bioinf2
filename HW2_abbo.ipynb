# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.1

# %%
#we had downloaded the Curated gene list for disease C1621958 from disgenet. let's open the file
disgenet=pd.read_csv('browser_source_summary_gda_CURATED.tsv', sep="\t")

# %%
##let's see how it looks like
# disgenet

# %%
#now let's save the gene symbols, entrez ID and names in arrays
symbol=[]
names=[]
entrezID=[]
for i in range(len(disgenet)):
#     print(disgenet['Gene'][i]+" ")
    symbol.append(disgenet['Gene'][i])
    names.append(disgenet['Gene_Full_Name'][i])
    entrezID.append(disgenet['Gene_id'][i])
    
#we check on HGNC to see if we need to change genes name

# %%
# we need to change
# H2AFX H2AX
# H3F3A H3-3A
# HIST1H3A H3C1 
# HIST1H3B H3C2 
# SEPT14 SEPTIN14

for i in range(len(symbol)):
    if symbol[i]=='H2AFX':
        symbol[i]='H2AX'
    if symbol[i]=='H3F3A':
        symbol[i]='H3-3A'
    if symbol[i]=='HIST1H3A':
        symbol[i]='H3C1'
    if symbol[i]=='HIST1H3B':
        symbol[i]='H3C2'
    if symbol[i]=='SEPT14':
        symbol[i]='SEPTIN14'
#     print(symbol[i]+ ",")

# %%
#with our genes name fixed we have seen the list of uniprot genes ID and saved it
uniprot=pd.read_csv('download.csv',sep=";")

# %%
## it looks like this
# uniprot

# %%
#let's save that IDs in array.
uniprotAC=[]
for i in range(len(uniprot)):
#     print(uniprot['Entry'][i]+" ")
    uniprotAC.append(uniprot['Entry'][i])

# %%
#ADD THE DESCRIPTION COLUMN!

# %%
#save our data to a new df
results = pd.DataFrame(list(zip(symbol,names,entrezID,uniprotAC)), columns=['Symbol','Name','ID','UniprotAC'])
results.to_csv('Results.csv')

# %%
results
# Out:
#        Symbol                                               Name      ID  \
# 0        JAG1                                           jagged 1     182
# 1         APC               APC, WNT signaling pathway regulator     324
# 2        ATRX                          ATRX, chromatin remodeler     546
# 3        BCHE                              butyrylcholinesterase     590
# 4        BMI1          BMI1 proto-oncogene, polycomb ring finger     648
# ..        ...                                                ...     ...
# 98      PINK1                     PTEN induced putative kinase 1   65018
# 99      TAF1L  TATA-box binding protein associated factor 1 like  138474
# 100      SIK1                            salt inducible kinase 1  150094
# 101    STKLD1   serine/threonine kinase like domain containing 1  169436
# 102  SEPTIN14                                          septin 14  346288
#
#     UniprotAC
# 0      P78504
# 1      P25054
# 2      P46100
# 3      P06276
# ...

# %%
## print the uniprot ID in order to search on IID database
# for i in range(len(uniprotAC)):
#     print(uniprotAC[i]+ ",")

# %% [markdown]
# # 1.2

# %%
#open biogrid DB
biogrid=pd.read_csv('BIOGRID-ALL-3.5.179.txt', sep='\t')

# %%
 biogrid.head(5)
# Out:
#   INTERACTOR_A INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 0      ETG6416      ETG2318            MAP2K4              FLNC
# 1     ETG84665        ETG88              MYPN             ACTN2
# 2        ETG90      ETG2339             ACVR1              FNTA
# 3      ETG2624      ETG5371             GATA2               PML
# 4  RP4-547C9.3      ETG6774              RPA2             STAT3
#
#                                        ALIASES_FOR_A  \
# 0  JNKK|JNKK1|MAPKK4|MEK4|MKK4|PRKMK4|SAPKK-1|SAP...
# 1                             CMD1DD|CMH22|MYOP|RCM4
# 2            ACTRI|ACVR1A|ACVRLK2|ALK2|FOP|SKR1|TSRI
# 3                           DCML|IMD21|MONOMAC|NFE1B
# 4                      REPA2|RP-A p32|RP-A p34|RPA32
#
#                               ALIASES_FOR_B EXPERIMENTAL_SYSTEM  \
# 0  ABP-280|ABP280A|ABPA|ABPL|FLN2|MFM5|MPD4          Two-hybrid
# 1                                    CMD1AA          Two-hybrid
# ...

# %%
#let's select what we want from the biogrid dataset.
#select only human PPI
biogrid_human=biogrid.loc[(biogrid['ORGANISM_A_ID']==9606) & (biogrid['ORGANISM_B_ID']==9606)]
biogrid_human.head(5)
# Out:
#   INTERACTOR_A INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 0      ETG6416      ETG2318            MAP2K4              FLNC
# 1     ETG84665        ETG88              MYPN             ACTN2
# 2        ETG90      ETG2339             ACVR1              FNTA
# 3      ETG2624      ETG5371             GATA2               PML
# 4  RP4-547C9.3      ETG6774              RPA2             STAT3
#
#                                        ALIASES_FOR_A  \
# 0  JNKK|JNKK1|MAPKK4|MEK4|MKK4|PRKMK4|SAPKK-1|SAP...
# 1                             CMD1DD|CMH22|MYOP|RCM4
# 2            ACTRI|ACVR1A|ACVRLK2|ALK2|FOP|SKR1|TSRI
# 3                           DCML|IMD21|MONOMAC|NFE1B
# 4                      REPA2|RP-A p32|RP-A p34|RPA32
#
#                               ALIASES_FOR_B EXPERIMENTAL_SYSTEM  \
# 0  ABP-280|ABP280A|ABPA|ABPL|FLN2|MFM5|MPD4          Two-hybrid
# 1                                    CMD1AA          Two-hybrid
# ...

# %%
#select only interaction on our seed genes
biogrid_seed=biogrid_human.loc[(biogrid_human['OFFICIAL_SYMBOL_A'].isin(symbol)) | (biogrid_human['OFFICIAL_SYMBOL_B'].isin(symbol))]
biogrid_seed.head(5) #seed
# Out:
#     INTERACTOR_A INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 3        ETG2624      ETG5371             GATA2               PML
# 49       ETG1033      ETG1017             CDKN3              CDK2
# 63       ETG1634      ETG1956               DCN              EGFR
# 142      ETG5747      ETG3667              PTK2              IRS1
# 143      ETG5599      ETG3667             MAPK8              IRS1
#
#                                          ALIASES_FOR_A  \
# 3                             DCML|IMD21|MONOMAC|NFE1B
# 49                                  CDI1|CIP2|KAP|KAP1
# 63                    CSCD|DSPG2|PG40|PGII|PGS2|SLRR1B
# 142        FADK|FAK|FAK1|FRNK|PPP1R71|p125FAK|pp125FAK
# 143  JNK|JNK-46|JNK1|JNK1A2|JNK21B1/2|PRKM8|SAPK1|S...
#
#                          ALIASES_FOR_B EXPERIMENTAL_SYSTEM            SOURCE  \
# 3              MYL|PP8675|RNF71|TRIM19          Two-hybrid  Tsuzuki S (2000)
# 49                     CDKN2|p33(CDK2)          Two-hybrid     Yeh CT (2003)
# ...

# %%
#now let's search fot genes not in our list, they may have interaction among them.
#save them into a list

#select all interaction where one of two interactor is not one seed gene
non_seed_df=biogrid_seed.loc[~(biogrid_seed['OFFICIAL_SYMBOL_A'].isin(symbol)) | (biogrid_seed['OFFICIAL_SYMBOL_B'].isin(symbol))]
#reset index
non_seed_df=non_seed_df.reset_index(drop=True)
#create empty list
non_seed_list=[]
#fill the list
for i in range(len(non_seed_df)):
    if non_seed_df['OFFICIAL_SYMBOL_A'][i] not in symbol:
        non_seed_list.append(non_seed_df['OFFICIAL_SYMBOL_A'][i])
    if non_seed_df['OFFICIAL_SYMBOL_B'][i] not in symbol:
        non_seed_list.append(non_seed_df['OFFICIAL_SYMBOL_B'][i])

# %%
#now search for non seed interactions from the human DB

#reset index
biogrid_human=biogrid_human.reset_index(drop=True)
#create a list of index of the original matrix with non seed interaction to save
idx=[]
#fill the list
for i in range(len(biogrid_human)):
    if biogrid_human['OFFICIAL_SYMBOL_A'][i] in non_seed_list and biogrid_human['OFFICIAL_SYMBOL_B'][i] in non_seed_list:
        idx.append(i)

# %%
biogrid_noseed=biogrid_human.loc[idx]
biogrid_noseed.head(5)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#    INTERACTOR_A  INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 4   RP4-547C9.3       ETG6774              RPA2             STAT3
# 5        ETG375      ETG23163              ARF1              GGA3
# 12  RP1-85F18.1  RP1-290I10.1             EP300            TFAP2A
# 15      ETG1436       ETG2885             CSF1R              GRB2
# 21       ETG672        ETG466             BRCA1              ATF1
#
#                                         ALIASES_FOR_A  \
# 4                       REPA2|RP-A p32|RP-A p34|RPA32
# 5                                                   -
# ...

# %%
## now let's open the IID database
iid=pd.read_csv('PPIs.txt', sep='\t')
iid.head(5)
# Out:
#   UniProt1 UniProt2  symbol1  symbol2 evidence type  glioblastoma multiforme
# 0   O14503   Q15910  BHLHE40     EZH2           exp                        1
# 1   O14503   Q00987  BHLHE40     MDM2           exp                        1
# 2   O14503   P08670  BHLHE40      VIM           exp                        1
# 3   O14503   Q12824  BHLHE40  SMARCB1           exp                        1
# 4   O14503   P68400  BHLHE40  CSNK2A1           exp                        1

# %%
biogrid_seed
# Out:
#           INTERACTOR_A INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 3              ETG2624      ETG5371             GATA2               PML
# 49             ETG1033      ETG1017             CDKN3              CDK2
# 63             ETG1634      ETG1956               DCN              EGFR
# 142            ETG5747      ETG3667              PTK2              IRS1
# 143            ETG5599      ETG3667             MAPK8              IRS1
# ...                ...          ...               ...               ...
# 1729770   RP11-817I4.1      ETG3654             BICD1             IRAK1
# 1729865  RP11-476B13.3     ETG26136             BICD2               TES
# 1730139       ETG84376       ETG324             HOOK3               APC
# 1730304       ETG51199       ETG324               NIN               APC
# 1730404   RP4-691N24.1      ETG9611              NINL             NCOR1
#
#                                              ALIASES_FOR_A  \
# ...

# %%
biogrid_noseed.head(1)
# Out:
#   INTERACTOR_A INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 4  RP4-547C9.3      ETG6774              RPA2             STAT3
#
#                    ALIASES_FOR_A    ALIASES_FOR_B EXPERIMENTAL_SYSTEM  \
# 4  REPA2|RP-A p32|RP-A p34|RPA32  ADMIO|APRF|HIES          Two-hybrid
#
#          SOURCE   PUBMED_ID  ORGANISM_A_ID  ORGANISM_B_ID
# 4  Kim J (2000)  10875894.0         9606.0         9606.0

# %% [markdown]
# - a  For each seed gene, collect all binary protein interactions from two different PPI sources:
# - i) Biogrid Human, latest release available
# - ii) IID Integrated Interactions Database (experimental data only, all tissues, unless
#     stated otherwise in further instruction

# %%
int_seed = biogrid_seed.OFFICIAL_SYMBOL_A.isin(iid.symbol1) 
int_seed2=biogrid_seed.OFFICIAL_SYMBOL_A.isin(iid.symbol2)
int_seed3=biogrid_seed.OFFICIAL_SYMBOL_B.isin(iid.symbol1)
int_seed4=biogrid_seed.OFFICIAL_SYMBOL_B.isin(iid.symbol2)  

interaction1=biogrid_seed[int_seed]
interaction2=interaction1[int_seed2]
interaction3=interaction2[int_seed3]
interaction_biogrid_seed=interaction3[int_seed4]

# %%
interaction_biogrid_seed.head()
# Out:
#        INTERACTOR_A   INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 63          ETG1634        ETG1956               DCN              EGFR
# 120341      ETG1017        ETG1027              CDK2            CDKN1B
# 120418      ETG1956  RP11-307C12.1              EGFR              SHC1
# 120422      ETG1956        ETG1398              EGFR               CRK
# 120426      ETG2064  RP11-307C12.1             ERBB2              SHC1
#
#                                          ALIASES_FOR_A  \
# 63                    CSCD|DSPG2|PG40|PGII|PGS2|SLRR1B
# 120341                                 CDKN2|p33(CDK2)
# 120418               ERBB|ERBB1|HER1|NISBD2|PIG61|mENA
# 120422               ERBB|ERBB1|HER1|NISBD2|PIG61|mENA
# 120426  CD340|HER-2|HER-2/neu|HER2|MLN 19|NEU|NGL|TKR1
#
#                             ALIASES_FOR_B       EXPERIMENTAL_SYSTEM  \
# 63      ERBB|ERBB1|HER1|NISBD2|PIG61|mENA                Two-hybrid
# ...

# %%
int_noseed = biogrid_noseed.OFFICIAL_SYMBOL_A.isin(iid.symbol1) 
int_noseed2=biogrid_noseed.OFFICIAL_SYMBOL_A.isin(iid.symbol2)
int_noseed3=biogrid_noseed.OFFICIAL_SYMBOL_B.isin(iid.symbol1)
int_noseed4=biogrid_noseed.OFFICIAL_SYMBOL_B.isin(iid.symbol2)  

interaction1_no=biogrid_noseed[int_noseed]
interaction2_no=interaction1_no[int_noseed2]
interaction3_no=interaction2_no[int_noseed3]
interaction_biogrid_noseed=interaction3_no[int_noseed4]
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
interaction_biogrid_noseed.head()
# Out:
#        INTERACTOR_A   INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 22           ETG672        ETG4436             BRCA1              MSH2
# 87      OK/SW-cl.43  RP11-399O19.7             SUMO1               FAS
# 222         ETG2321  RP11-307C12.1              FLT1              SHC1
# 123607       ETG472         ETG672               ATM             BRCA1
# 123808      ETG4436   RP11-436C9.1              MSH2             CHEK2
#
#                                             ALIASES_FOR_A  \
# 22      BRCAI|BRCC1|BROVCA1|FANCS|IRIS|PNCA4|PPP1R53|P...
# 87      DAP1|GMP1|OFC10|PIC1|SENP2|SMT3|SMT3C|SMT3H3|UBL1
# 222                              FLT|FLT-1|VEGFR-1|VEGFR1
# 123607                AT1|ATA|ATC|ATD|ATDC|ATE|TEL1|TELO1
# 123808                      COCA1|FCC1|HNPCC|HNPCC1|LCFS2
#
#                                             ALIASES_FOR_B  \
# 22                          COCA1|FCC1|HNPCC|HNPCC1|LCFS2
# 87              ALPS1A|APO-1|APT1|CD95|FAS1|FASTM|TNFRSF6
# ...

# %% [markdown]
# - b) Store the data gathered from the two DBs in two different tables/matrices in an easily accessible format of your choice (csv, tab, excel, etc).

# %%
interaction_biogrid_seed.to_csv('bioseed', sep='\t', encoding='utf-8')
interaction_biogrid_noseed.to_csv('bionoseed', sep='\t', encoding='utf-8')

# %% [markdown]
# -   c) Summarize the main results in a table reporting:
#  - a) number of seed genes found in each different DBs (some seed genes may be missing
#     in the DBs);
#  - b) total no. of interacting proteins, including seed genes, for each DB;
#  - c) total no. of interactions found in each DB.

# %%
#a
len(interaction_biogrid_seed.OFFICIAL_SYMBOL_A.unique()) #148
len(interaction_biogrid_seed.OFFICIAL_SYMBOL_B.unique()) #170
len(np.unique(interaction_biogrid_seed[['OFFICIAL_SYMBOL_A', 'OFFICIAL_SYMBOL_B']].values))#175
#b?????
#c????
# Out:
# 175

# %% [markdown]
# ### 1.3) Arrange interaction data
# Build and store three tables:
# - a) seed genes interactome: interactions that involve seed genes only, from all DBs, in
# the format:
# interactor A gene symbol, interactor B gene symbol, interactor A Uniprot AC, interactor B
# Uniprot AC, database source
# - b) union interactome: all proteins interacting with at least one seed gene, from all DBs,
# same format as above.
# - c) intersection interactome: all proteins interacting with at least one seed gene confirmed
# by both DBs, in the format:
# interactor A gene symbol, interactor B gene symbol, interactor A Uniprot AC, interactor B
# Uniprot AC
# Always check that interactors are both human (i.e. organism ID is always 9606, Homo
# Sapiens)

# %%
iid.rename({'symbol1': 'OFFICIAL_SYMBOL_A', 'symbol2': 'OFFICIAL_SYMBOL_B'}, axis=1, inplace=True)

# %%
seedgenesinteractome= pd.merge(interaction_biogrid_seed, iid,
                         on=['OFFICIAL_SYMBOL_A','OFFICIAL_SYMBOL_B'])

# %%
seedgenesinteractome=seedgenesinteractome[['INTERACTOR_A','OFFICIAL_SYMBOL_A', 'INTERACTOR_B','OFFICIAL_SYMBOL_B','ALIASES_FOR_A', 'UniProt1','ALIASES_FOR_B', 'UniProt2']]

# %%
seedgenesinteractome
# Out:
#      INTERACTOR_A OFFICIAL_SYMBOL_A  INTERACTOR_B OFFICIAL_SYMBOL_B  \
# 0         ETG1017              CDK2       ETG1027            CDKN1B
# 1         ETG1017              CDK2       ETG1027            CDKN1B
# 2         ETG1017              CDK2       ETG1027            CDKN1B
# 3         ETG1017              CDK2       ETG1027            CDKN1B
# 4         ETG1017              CDK2       ETG1027            CDKN1B
# ...           ...               ...           ...               ...
# 1174      ETG7157              TP53  RP5-875J14.1              ATRX
# 1175      ETG7157              TP53  RP5-875J14.1              ATRX
# 1176      ETG4609               MYC   DADB-17J1.3              BRD2
# 1177      ETG4609               MYC       ETG1457           CSNK2A1
# 1178      ETG1785              DNM2       ETG5747              PTK2
#
#                                      ALIASES_FOR_A UniProt1  \
# 0                                  CDKN2|p33(CDK2)   P24941
# ...
